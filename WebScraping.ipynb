# %%
import pandas as pd
import requests
import yfinance as yf
from bs4 import BeautifulSoup
import warnings
# Ignore all warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
# 1. Extracting Tesla Stock Data Using yfinance
# Download Tesla stock data
tesla = yf.Ticker("TSLA")
tesla_data = tesla.history(period="max")

# Display the first few rows
tesla_data.head()
# Out:
#                                Open      High       Low     Close     Volume  \
# Date
# 2010-06-29 00:00:00-04:00  1.266667  1.666667  1.169333  1.592667  281494500
# 2010-06-30 00:00:00-04:00  1.719333  2.028000  1.553333  1.588667  257806500
# 2010-07-01 00:00:00-04:00  1.666667  1.728000  1.351333  1.464000  123282000
# 2010-07-02 00:00:00-04:00  1.533333  1.540000  1.247333  1.280000   77097000
# 2010-07-06 00:00:00-04:00  1.333333  1.333333  1.055333  1.074000  103003500
#
#                            Dividends  Stock Splits
# Date
# 2010-06-29 00:00:00-04:00        0.0           0.0
# 2010-06-30 00:00:00-04:00        0.0           0.0
# 2010-07-01 00:00:00-04:00        0.0           0.0
# 2010-07-02 00:00:00-04:00        0.0           0.0
# 2010-07-06 00:00:00-04:00        0.0           0.0

# %%
# 2. Extracting Tesla Stock Data Using WebScrapping
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Define the URL
url = "https://companiesmarketcap.com/tesla/revenue/"
data = requests.get(url).text
# Parse the HTML using BeautifulSoup
soup = BeautifulSoup(data, "html.parser")

# Find the table body
table = soup.find("table")

# Extract all rows
rows = table.find("tbody").find_all("tr")

# Store extracted data
tesla_revenue_data = []

# Loop through rows and extract relevant columns
for row in rows:
    cols = row.find_all("td")
    year = cols[0].text.strip()[:4]  # Extract the year
    revenue = cols[1].text.strip().replace("$", "").replace(" B", "")  # Extract revenue
    change = cols[2].text.strip() if len(cols) > 2 else ""  # Extract change percentage
    
    tesla_revenue_data.append([year, revenue, change])

# Create a DataFrame
tesla_revenue = pd.DataFrame(tesla_revenue_data, columns=["Year", "Revenue (Billion $)", "Change (%)"])

# Convert Revenue to float
tesla_revenue["Revenue (Billion $)"] = tesla_revenue["Revenue (Billion $)"].astype(float)

# Display extracted data
print(df)
# Out:
#     Year  Revenue (Billion $) Change (%)
# 0   2024                 4.53    -14.08%
# 1   2023                 5.27    -11.04%
# 2   2022                 5.92     -1.39%
# 3   2021                 6.01     18.09%
# 4   2020                 5.08    -21.28%
# 5   2019                 6.46    -17.55%
# 6   2018                 7.84    -14.98%
# 7   2017                 9.22      7.16%
# 8   2016                 8.60     -8.07%
# 9   2015                 9.36      0.73%
# 10  2014                 9.29      2.84%
# 11  2013                 9.03      1.72%
# 12  2012                 8.88     -6.95%
# 13  2011                 9.55      0.81%
# 14  2010                 9.47      4.36%
# 15  2009                 9.07      3.09%
# 16  2008                 8.80     24.13%
# 17  2007                 7.09     33.37%
# 18  2006                 5.31     72.03%
# 19  2005                 3.09     67.78%
# 20  2004                 1.84     16.72%
# 21  2003                 1.57     16.71%
# ...

# %%
# 3. Extracting GameStop stock data using yfinance
gme = yf.Ticker("GME")
gme_data = gme.history(period="max")
gme_data.head()
# Out:
#                                Open      High       Low     Close    Volume  \
# Date
# 2002-02-13 00:00:00-05:00  1.620128  1.693349  1.603295  1.691666  76216000
# 2002-02-14 00:00:00-05:00  1.712707  1.716074  1.670626  1.683250  11021600
# 2002-02-15 00:00:00-05:00  1.683251  1.687459  1.658002  1.674834   8389600
# 2002-02-19 00:00:00-05:00  1.666418  1.666418  1.578047  1.607504   7410400
# 2002-02-20 00:00:00-05:00  1.615920  1.662210  1.603296  1.662210   6892800
#
#                            Dividends  Stock Splits
# Date
# 2002-02-13 00:00:00-05:00        0.0           0.0
# 2002-02-14 00:00:00-05:00        0.0           0.0
# 2002-02-15 00:00:00-05:00        0.0           0.0
# 2002-02-19 00:00:00-05:00        0.0           0.0
# 2002-02-20 00:00:00-05:00        0.0           0.0

# %%
# Extracting GameStop stock data using WebScraping
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Define the URL
url = "https://companiesmarketcap.com/gamestop/revenue/"
data = requests.get(url).text
# Parse the HTML using BeautifulSoup
soup = BeautifulSoup(data, "html.parser")

# Find the table body
table = soup.find("table")

# Extract all rows
rows = table.find("tbody").find_all("tr")

# Store extracted data
gme_revenue_data = []

# Loop through rows and extract relevant columns
for row in rows:
    cols = row.find_all("td")
    year = cols[0].text.strip()[:4]  # Extract the year
    revenue = cols[1].text.strip().replace("$", "").replace(" B", "")  # Extract revenue
    change = cols[2].text.strip() if len(cols) > 2 else ""  # Extract change percentage
    
    gme_revenue_data.append([year, revenue, change])

# Create a DataFrame
gme_revenue = pd.DataFrame(gme_revenue_data, columns=["Year", "Revenue (Billion $)", "Change (%)"])

# Convert Revenue to float
gme_revenue["Revenue (Billion $)"] = gme_revenue["Revenue (Billion $)"].astype(float)

# Display extracted data
print(df)
# Out:
#     Year  Revenue (Billion $) Change (%)
# 0   2024                 4.53    -14.08%
# 1   2023                 5.27    -11.04%
# 2   2022                 5.92     -1.39%
# 3   2021                 6.01     18.09%
# 4   2020                 5.08    -21.28%
# 5   2019                 6.46    -17.55%
# 6   2018                 7.84    -14.98%
# 7   2017                 9.22      7.16%
# 8   2016                 8.60     -8.07%
# 9   2015                 9.36      0.73%
# 10  2014                 9.29      2.84%
# 11  2013                 9.03      1.72%
# 12  2012                 8.88     -6.95%
# 13  2011                 9.55      0.81%
# 14  2010                 9.47      4.36%
# 15  2009                 9.07      3.09%
# 16  2008                 8.80     24.13%
# 17  2007                 7.09     33.37%
# 18  2006                 5.31     72.03%
# 19  2005                 3.09     67.78%
# 20  2004                 1.84     16.72%
# 21  2003                 1.57     16.71%
# ...

# %%
# !pip install dash
import dash
from dash import dcc, html
import pandas as pd
import plotly.express as px

# Create a revenue growth chart
fig_revenue = px.line(
    tesla_revenue, x="Year", y="Revenue (Billion $)", markers=True,
    title="Tesla Annual Revenue Growth",
    labels={"Revenue (Billion $)": "Revenue (Billion $)", "Year": "Year"}
)

# Create a percentage change chart
fig_change = px.bar(
    tesla_revenue, x="Year", y="Change (%)", color="Change (%)",
    title="Tesla Revenue Change (%) Per Year",
    labels={"Change (%)": "Change (%)", "Year": "Year"}
)

# Dash App
app = dash.Dash(__name__)

app.layout = html.Div(children=[
    html.H1("Tesla Stock and Revenue Dashboard", style={'textAlign': 'center'}),

    dcc.Graph(id="revenue-chart", figure=fig_revenue),

    dcc.Graph(id="change-chart", figure=fig_change),

    # Placeholder for stock price data (can be connected to an API)
    html.H3("Tesla Stock Price (Live Data Coming Soon)", style={'textAlign': 'center'}),
    dcc.Graph(id="stock-price-chart")
])

if __name__ == '__main__':
    app.run(debug=True)
# Out:
# ...
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# !pip install dash
import dash
from dash import dcc, html
import pandas as pd
import plotly.express as px

# Create a revenue growth chart
fig_revenue = px.line(
    gme_revenue, x="Year", y="Revenue (Billion $)", markers=True,
    title="GameStop Annual Revenue Growth",
    labels={"Revenue (Billion $)": "Revenue (Billion $)", "Year": "Year"}
)

# Create a percentage change chart
fig_change = px.bar(
    gme_revenue, x="Year", y="Change (%)", color="Change (%)",
    title="GameStop Revenue Change (%) Per Year",
    labels={"Change (%)": "Change (%)", "Year": "Year"}
)

# Dash App
app = dash.Dash(__name__)

app.layout = html.Div(children=[
    html.H1("GameStop Stock and Revenue Dashboard", style={'textAlign': 'center'}),

    dcc.Graph(id="revenue-chart", figure=fig_revenue),

    dcc.Graph(id="change-chart", figure=fig_change),

    # Placeholder for stock price data (can be connected to an API)
    html.H3("GameStop Stock Price (Live Data Coming Soon)", style={'textAlign': 'center'}),
    dcc.Graph(id="stock-price-chart")
])

if __name__ == '__main__':
    app.run(debug=True)
# Out:
# ...
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
